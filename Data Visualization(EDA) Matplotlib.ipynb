# %% [markdown]
# # Barplot

# %%
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline
 
# Make a fake dataset:
Marks = [10, 20,30, 40, 50]
Students = ['Jay', 'Ray', 'Jangali', 'Jenny', 'Eli']
y = np.arange(len(Students))
 
# Create bars
plt.bar(y, Marks)
 
# Create names on the x-axis
plt.xticks(y, Students)
 
# Show graphic
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\LENOVO\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\LENOVO\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# insigth  = jenny(17.5) is having haighest score and lowest score is Genelia(5.0)

# %%
# Make fake dataset
Marks = [12, 13, 5, 18, 11]
Students = ['Jay', 'Ray', 'Genelia', 'Jenny', 'Eli']
y_pos = np.arange(len(Students))
 
# Create horizontal bars
plt.barh(y_pos, Marks)
 
# Create names on the y-axis
plt.yticks(y_pos, Students)
     
# Show graphic
plt.show()

# %%
# Make fake dataset
Marks = [12, 13, 5, 18, 11]
Students = ['Jay', 'Ray', 'Genelia', 'Jenny', 'Eli']
y_pos = np.arange(len(Students))

plt.bar(y_pos, Marks, color=["#0091e4"], edgecolor='black')
plt.xticks(y_pos, Students)
plt.show()

# %%
# Make fake dataset
Marks = [12, 13, 5, 18, 11]
Students = ['Jay', 'Ray', 'Genelia', 'Jenny', 'Eli']
y_pos = np.arange(len(Students))

plt.bar(y_pos, Marks, color=["#FFCCE5"], edgecolor='Green')
plt.xticks(y_pos, Students)
plt.show()

# %%
# Make fake dataset
Marks = [12, 13, 5, 18, 11]
Students = ['Jay', 'Ray', 'Genelia', 'Jenny', 'Eli']
y_pos = np.arange(len(Students))

plt.bar(y_pos, Marks, color=['grey', 'orange', 'Yellow', 'pink', 'Blue'], edgecolor='black')
plt.xticks(y_pos, Students)
plt.show()

# %%
# Make fake dataset
height = [12, 13, 5, 18, 11]
Students = ['Jay', 'Ray', 'Genelia', 'Jenny', 'Eli']
# Choose the position of each barplots on the x-axis (space=1,4,3,1)
y_pos = [0,1,2,4,6]
 
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis
plt.xticks(y_pos, Students)
 
# Show graphic
plt.show()

# %%
# Choose the height of the bars
height = [3, 12, 5, 18, 45]
 
# Choose the names of the bars
bars = ('group1', 'group2', 'group3', 'group4', 'group5')
y_pos = np.arange(len(bars))
 
# Create bars
plt.bar(y_pos, height)
 
# Create names on the x-axis
plt.xticks(y_pos, bars, color='orange')
plt.yticks(color='orange')

# to control size of label, font and color of axis
plt.xlabel('category', fontweight='bold', color = 'Blue', fontsize='20')
plt.ylabel('Values', fontweight='bold', color = 'green', fontsize='18')


# Show graphic
plt.show()

# %%
# Create data
height = [3, 12, 5, 18, 45]
bars = ("very long group name 1","very long group name 2","very long group name 3","very long group name 4","very long group name 5")
y_pos = np.arange(len(bars))

# Create bars
plt.bar(y_pos, height)
 
# Rotation of the bars names
plt.xticks(y_pos, bars, rotation=45)
 
# Custom the subplot layout
plt.subplots_adjust(bottom=0.4, top=0.90)
#plt.subplots_adjust(bottom=0.99, top=0.10)
# Show graphic
plt.show()

# %%
barWidth = 0.9
bars1 = [3, 3, 1]
bars2 = [4, 2, 3]
bars3 = [4, 6, 7, 10, 4, 4]
bars4 = bars1 + bars2 + bars3
 
# The X position of bars
r1 = [1,5,9]
r2 = [2,6,10]
r3 = [3,4,7,8,11,12]
r4 = r1 + r2 + r3
 
# Create barplot
plt.bar(r1, bars1, width = barWidth, color = (0.3,0.1,0.4,0.6), label='Alone')
plt.bar(r2, bars2, width = barWidth, color = (0.3,0.5,0.4,0.6), label='With Himself')
plt.bar(r3, bars3, width = barWidth, color = (0.3,0.9,0.4,0.6), label='With other genotype')
# Note: the barplot could be created easily. See the barplot section for other examples.
 
# Create legend
plt.legend()
 
# Text below each barplot with a rotation at 90°
plt.xticks([r + barWidth for r in range(len(r4))], ['DD', 'with himself', 'with DC', 'with Silur', 'DC', 'with himself', 'with DD', 'with Silur', 'Silur', 'with himself', 'with DD', 'with DC'], rotation=90)
 
# Create labels
label = ['n = 6', 'n = 25', 'n = 13', 'n = 36', 'n = 30', 'n = 11', 'n = 16', 'n = 37', 'n = 14', 'n = 4', 'n = 31', 'n = 34']
 
# Text on the top of each barplot
for i in range(len(r4)):
    plt.text(x = r4[i]-0.5 , y = bars4[i]+0.1, s = label[i], size = 6)
 


   ##Adjust the margins
plt.subplots_adjust(bottom= 0.10, top = 0.98)
 
# Show graphic
plt.show()

# %% [markdown]
# # Stacked Barplot

# %%
import matplotlib.pyplot as plt

A = [5., 30., 45., 22.]
B = [5., 25., 50., 20.]

X = range(4)

plt.bar(X, A, color = 'lightgreen')
plt.bar(X, B, color = 'green', bottom = A)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

A = np.array([5., 30., 45., 22.])
B = np.array([5., 25., 50., 20.])
C = np.array([1.5,  2.5,  1.8,  1.9])
X = np.arange(4)

plt.bar(X, A, color = 'blue', edgecolor = "black")
plt.bar(X, B, color = 'lightgreen', bottom = A, edgecolor = "black")
plt.bar(X, C, color = 'magenta', bottom = A + B, edgecolor = "black")
plt.show()

# %%
# column bar chart/ subchart

import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.show()

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np
#%matplotlib inline

# generating random values for histogram
x = np.random.randn(1000)  
# plotting histogram with 15 bins
plt.hist(x, bins = 15)
plt.show()
## is thear are the varia

# %%
# generating random values for histogram
x = np.random.randn(120)  
# plotting histogram with 150 bins
plt.hist(x, bins = 10, color = "green", edgecolor = "black")
plt.xlabel('Values of X', fontweight='bold', color = 'black', fontsize='18')
plt.show()

# %% [markdown]
# # Boxplot

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
# Fixing random state for reproducibility
np.random.seed(19680801)
# fake up some data
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low))

# %%
fig1, ax1 = plt.subplots()
plt.title('Basic Plot')
plt.boxplot(data)
show()

# %%
red_diamond = dict(markerfacecolor='r', marker='D')
plt.title('Changed Outlier Symbols')
plt.boxplot(data, flierprops=red_diamond)
plt.show()

# %%
red_square = dict(markerfacecolor='r', marker='s')
plt.title('Horizontal Boxes')
plt.boxplot(data, vert=False, flierprops=red_square)
plt.show()

# %%
value1 = [82,76,24,40,67,62,75,78,71,32,98,89,78,67,72,82,87,66,56,52]
value2=[62,5,91,25,36,32,96,95,3,90,95,32,27,55,100,15,71,11,37,21]
value3=[23,89,12,78,72,89,25,69,68,86,19,49,15,16,16,75,65,31,25,52]
value4=[59,73,70,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]

box_plot_data=[value1,value2,value3,value4]
plt.boxplot(box_plot_data,patch_artist=True,labels=['course1','course2','course3','course4'])
plt.title("Multiple boxplots")
plt.xlabel("Groups")
plt.show()

# %% [markdown]
# # Line Chart

# %%
# create data
values=np.cumsum(np.random.randn(1000,1))
 
# use the plot function
plt.plot(values)
plt.show()

# %%
# libraries and data
import pandas as pd
df=pd.DataFrame({'xvalues': range(1,101), 'yvalues': np.random.randn(100) })
 
# plot
plt.plot( 'xvalues', 'yvalues', data=df, color = "red", alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Data
df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21)})
# multiple line plot
plt.plot( 'x', 'y1', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2)
plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.legend()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1736\3150024241.py:8: RuntimeWarning: Second argument 'y1' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot( 'x', 'y1', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1736\3150024241.py:9: RuntimeWarning: Second argument 'y2' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2)
# ...

# %% [markdown]
# # Scatter Plot

# %%
# Create a dataset:
df=pd.DataFrame({'x': range(1,101), 'y': np.random.randn(100)*15+range(1,101) })
 
# plot
plt.plot( 'x', 'y', data=df, linestyle='none', marker='o')
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1736\2854070236.py:5: RuntimeWarning: Second argument 'y' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot( 'x', 'y', data=df, linestyle='none', marker='o')

# %%
plt.plot( 'x', 'y', data=df, linestyle='none', marker='D', markersize=7)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1736\60634265.py:1: RuntimeWarning: Second argument 'y' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot( 'x', 'y', data=df, linestyle='none', marker='D', markersize=7)

# %%
plt.plot( 'x', 'y', data=df, linestyle='none', markerfacecolor='gold', marker="*", markeredgecolor="black", markersize=16, markeredgewidth=1.5)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1736\2951592138.py:1: RuntimeWarning: Second argument 'y' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot( 'x', 'y', data=df, linestyle='none', markerfacecolor='gold', marker="*", markeredgecolor="black", markersize=16, markeredgewidth=1.5)

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215, 130, 248, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

# Plot
# autopct is used to put text inside the wedges in a pie chart using string formating
plt.pie(sizes, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
(26.2+ 30.6+16.2+26.9)
# Out:
# 99.9

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some random data (in this case, 1000 random numbers)
data = np.random.randn(1000)

# Create a histogram
plt.hist(data, bins=30, edgecolor='k', alpha=0.7)

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')

# Show the plot
plt.show()

# %%
import seaborn as sns
import pandas as pd

# Assuming you have a DataFrame 'df' with your multivariable data
# Example data (replace this with your actual data)
data = {'Variable1': [1, 2, 3, 4, 5],
        'Variable2': [2, 3, 4, 3, 5],
        'Variable3': [3, 4, 5, 2, 6]}

df = pd.DataFrame(data)

# Create the scatter plot matrix
sns.pairplot(df, diag_kind='kde')  # 'kde' adds density plots along the diagonal

# Show the plot
plt.show()

# %% [markdown]
# Links to refer for Matplotlib
#
# https://matplotlib.org/stable/tutorials/index
# https://www.geeksforgeeks.org/matplotlib-tutorial/
